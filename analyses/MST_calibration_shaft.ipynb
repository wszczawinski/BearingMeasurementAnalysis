# %%
# libraries
import os
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#crate paths for csv files
CURR_DIR = os.getcwd()
print(CURR_DIR)
data_path = os.path.join(CURR_DIR, 'datasets/Calibration_shaft.csv')
# Out:
# /Users/w.szczawinski/Projects/master-thesis/analyses

# %%
shaft_measurments = pd.read_csv(data_path, sep=';', decimal=',')
shaft_measurments = shaft_measurments.astype(float)

# %%
shaft_measurments.head(-10)
# Out:
#            Count  Z measurement
# 0            1.0         5.5939
# 1            2.0         5.5939
# 2            3.0         5.5939
# 3            4.0         5.5939
# 4            5.0         5.5939
# ...          ...            ...
# 139608  139609.0       -84.2359
# 139609  139610.0       -84.2365
# 139610  139611.0       -84.2371
# 139611  139612.0       -84.2365
# 139612  139613.0       -84.2371
#
# [139613 rows x 2 columns]

# %%
shaft_measurments['Count'] = shaft_measurments['Count']%1000

shaft_measurments['Count'] = shaft_measurments['Count']*360/1000

# %%
shaft_measurments.head()
# Out:
#    Count  Z measurement
# 0   0.36         5.5939
# 1   0.72         5.5939
# 2   1.08         5.5939
# 3   1.44         5.5939
# 4   1.80         5.5939

# %%
plt.axes(projection = 'polar')

plt.plot(shaft_measurments['Z measurement'], shaft_measurments['Count'])
plt.rcParams['figure.figsize'] = [30, 7]
plt.show()
